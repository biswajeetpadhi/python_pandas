# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\python\python_pandas\Placement_Data_Full_Class.csv")

# %%
pd.set_option("display.max_rows", None)
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %%
df["salary"].plot(kind = "line")
# Out:
# <AxesSubplot:>

# %%
df.gender.value_counts().plot(kind = "pie", legend = True)
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
df.gender.value_counts()
# Out:
# M    139
# F     76
# Name: gender, dtype: int64

# %%
df[["gender", "status"]]
# Out:
#     gender      status
# 0        M      Placed
# 1        M      Placed
# 2        M      Placed
# 3        M  Not Placed
# 4        M      Placed
# 5        M  Not Placed
# 6        F  Not Placed
# 7        M      Placed
# 8        M      Placed
# 9        M  Not Placed
# 10       M      Placed
# 11       M      Placed
# 12       F  Not Placed
# 13       F      Placed
# 14       M  Not Placed
# 15       F      Placed
# 16       M      Placed
# 17       F  Not Placed
# 18       F  Not Placed
# 19       M      Placed
# 20       M      Placed
# 21       F      Placed
# 22       F      Placed
# 23       F      Placed
# 24       M      Placed
# 25       F  Not Placed
# 26       M      Placed
# 27       M      Placed
# 28       M      Placed
# 29       M  Not Placed
# 30       F      Placed
# 31       F  Not Placed
# 32       F      Placed
# 33       F      Placed
# 34       M  Not Placed
# 35       F      Placed
# 36       M  Not Placed
# 37       F      Placed
# 38       F      Placed
# ...

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
df.loc[:10]
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0       1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1       2      M  79.33  Central  78.33   Others   Science     77.48
# 2       3      M  65.00  Central  68.00  Central      Arts     64.00
# 3       4      M  56.00  Central  52.00  Central   Science     52.00
# 4       5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5       6      M  55.00   Others  49.80   Others   Science     67.25
# 6       7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7       8      M  82.00  Central  64.00  Central   Science     66.00
# 8       9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9      10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10     11      M  58.00  Central  61.00  Central  Commerce     60.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df.loc[0]
# Out:
# sl_no                    1
# gender                   M
# ssc_p                 67.0
# ssc_b               Others
# hsc_p                 91.0
# hsc_b               Others
# hsc_s             Commerce
# degree_p              58.0
# degree_t          Sci&Tech
# workex                  No
# etest_p               55.0
# specialisation      Mkt&HR
# mba_p                 58.8
# status              Placed
# salary            270000.0
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# sl_no                    1
# gender                   M
# ssc_p                 67.0
# ssc_b               Others
# hsc_p                 91.0
# hsc_b               Others
# hsc_s             Commerce
# degree_p              58.0
# degree_t          Sci&Tech
# workex                  No
# etest_p               55.0
# specialisation      Mkt&HR
# mba_p                 58.8
# status              Placed
# salary            270000.0
# Name: 0, dtype: object

# %%
df.iloc[[0]]
# Out:
#    sl_no gender  ssc_p   ssc_b  hsc_p   hsc_b     hsc_s  degree_p  degree_t  \
# 0      1      M   67.0  Others   91.0  Others  Commerce      58.0  Sci&Tech
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR   58.8  Placed  270000.0

# %%
df.iloc[[0, 1]]
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  degree_t  \
# 0      1      M  67.00   Others  91.00  Others  Commerce     58.00  Sci&Tech
# 1      2      M  79.33  Central  78.33  Others   Science     77.48  Sci&Tech
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR  58.80  Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0

# %%
df.iloc[0:4]
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN

# %%
df["hired"] = (df["status"] == "Placed")

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %%
df.drop(columns = ["hired"])
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %%
del df["hired"]

# %%
df.T
# Out:
#                      0         1          2           3          4    \
# sl_no                  1         2          3           4          5
# gender                 M         M          M           M          M
# ssc_p               67.0     79.33       65.0        56.0       85.8
# ssc_b             Others   Central    Central     Central    Central
# hsc_p               91.0     78.33       68.0        52.0       73.6
# hsc_b             Others    Others    Central     Central    Central
# hsc_s           Commerce   Science       Arts     Science   Commerce
# degree_p            58.0     77.48       64.0        52.0       73.3
# degree_t        Sci&Tech  Sci&Tech  Comm&Mgmt    Sci&Tech  Comm&Mgmt
# workex                No       Yes         No          No         No
# etest_p             55.0      86.5       75.0        66.0       96.8
# specialisation    Mkt&HR   Mkt&Fin    Mkt&Fin      Mkt&HR    Mkt&Fin
# mba_p               58.8     66.28       57.8       59.43       55.5
# ...

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %%
df.values
# Out:
# array([[1, 'M', 67.0, ..., 58.8, 'Placed', 270000.0],
#        [2, 'M', 79.33, ..., 66.28, 'Placed', 200000.0],
#        [3, 'M', 65.0, ..., 57.8, 'Placed', 250000.0],
#        ...,
#        [213, 'M', 67.0, ..., 69.72, 'Placed', 295000.0],
#        [214, 'F', 74.0, ..., 60.23, 'Placed', 204000.0],
#        [215, 'M', 62.0, ..., 60.22, 'Not Placed', nan]], dtype=object)

# %%
print(type(df.values))
# Out:
# <class 'numpy.ndarray'>

# %%
for row in df.values:
    print(row)
# Out:
# [1 'M' 67.0 'Others' 91.0 'Others' 'Commerce' 58.0 'Sci&Tech' 'No' 55.0
#  'Mkt&HR' 58.8 'Placed' 270000.0]
# [2 'M' 79.33 'Central' 78.33 'Others' 'Science' 77.48 'Sci&Tech' 'Yes'
#  86.5 'Mkt&Fin' 66.28 'Placed' 200000.0]
# [3 'M' 65.0 'Central' 68.0 'Central' 'Arts' 64.0 'Comm&Mgmt' 'No' 75.0
#  'Mkt&Fin' 57.8 'Placed' 250000.0]
# [4 'M' 56.0 'Central' 52.0 'Central' 'Science' 52.0 'Sci&Tech' 'No' 66.0
#  'Mkt&HR' 59.43 'Not Placed' nan]
# [5 'M' 85.8 'Central' 73.6 'Central' 'Commerce' 73.3 'Comm&Mgmt' 'No' 96.8
#  'Mkt&Fin' 55.5 'Placed' 425000.0]
# [6 'M' 55.0 'Others' 49.8 'Others' 'Science' 67.25 'Sci&Tech' 'Yes' 55.0
#  'Mkt&Fin' 51.58 'Not Placed' nan]
# [7 'F' 46.0 'Others' 49.2 'Others' 'Commerce' 79.0 'Comm&Mgmt' 'No' 74.28
#  'Mkt&Fin' 53.29 'Not Placed' nan]
# [8 'M' 82.0 'Central' 64.0 'Central' 'Science' 66.0 'Sci&Tech' 'Yes' 67.0
#  'Mkt&Fin' 62.14 'Placed' 252000.0]
# [9 'M' 73.0 'Central' 79.0 'Central' 'Commerce' 72.0 'Comm&Mgmt' 'No'
# ...

# %%
df1 = df[(df["gender"] == "M") & (df["status"] == "Placed")]

# %%
df1
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# 16      17      M  63.00  Central  66.20  Central  Commerce     65.60
# 19      20      M  60.00   Others  67.00   Others      Arts     70.00
# 20      21      M  62.00   Others  65.00   Others  Commerce     66.00
# 24      25      M  76.50   Others  97.70   Others   Science     78.86
# ...

# %%
df3 = df[(df["gender"] == "M") | (df["status"] == "Placed")]

# %%
df3
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# 13      14      F  77.00  Central  87.00  Central  Commerce     59.00
# ...

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %%
df5 = df.loc[df["gender"] == "M", ["gender","status"]]

# %%
df5
# Out:
#     gender      status
# 0        M      Placed
# 1        M      Placed
# 2        M      Placed
# 3        M  Not Placed
# 4        M      Placed
# 5        M  Not Placed
# 7        M      Placed
# 8        M      Placed
# 9        M  Not Placed
# 10       M      Placed
# 11       M      Placed
# 14       M  Not Placed
# 16       M      Placed
# 19       M      Placed
# 20       M      Placed
# 24       M      Placed
# 26       M      Placed
# 27       M      Placed
# 28       M      Placed
# 29       M  Not Placed
# 34       M  Not Placed
# 36       M  Not Placed
# 39       M      Placed
# 42       M  Not Placed
# 43       M      Placed
# 47       M      Placed
# 48       M      Placed
# 51       M  Not Placed
# 53       M      Placed
# 55       M      Placed
# 56       M      Placed
# 57       M      Placed
# 58       M      Placed
# 59       M      Placed
# 60       M      Placed
# 61       M      Placed
# 63       M  Not Placed
# 64       M      Placed
# 65       M  Not Placed
# ...

# %%
df5 = df.loc[(df["gender"] == "M") & (df["status"] == "Placed"), ["gender","status"]]

# %%
df5
# Out:
#     gender  status
# 0        M  Placed
# 1        M  Placed
# 2        M  Placed
# 4        M  Placed
# 7        M  Placed
# 8        M  Placed
# 10       M  Placed
# 11       M  Placed
# 16       M  Placed
# 19       M  Placed
# 20       M  Placed
# 24       M  Placed
# 26       M  Placed
# 27       M  Placed
# 28       M  Placed
# 39       M  Placed
# 43       M  Placed
# 47       M  Placed
# 48       M  Placed
# 53       M  Placed
# 55       M  Placed
# 56       M  Placed
# 57       M  Placed
# 58       M  Placed
# 59       M  Placed
# 60       M  Placed
# 61       M  Placed
# 64       M  Placed
# 66       M  Placed
# 67       M  Placed
# 69       M  Placed
# 70       M  Placed
# 71       M  Placed
# 72       M  Placed
# 73       M  Placed
# 74       M  Placed
# 77       M  Placed
# 78       M  Placed
# 81       M  Placed
# 83       M  Placed
# 84       M  Placed
# 86       M  Placed
# 94       M  Placed
# 95       M  Placed
# 101      M  Placed
# 103      M  Placed
# ...
